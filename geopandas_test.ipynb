# %%
import geopandas as gpd

# %%
gpd.GeoDataFrame({"type":"FeatureCollection","features":[{"type":"Feature","geometry":{"type":"MultiPolygon","coordinates":[[[[127.2600103453,36.5222237358],[127.2600103453,36.5262684443],[127.2650686665,36.5262684443],[127.2650686665,36.5222237358],[127.2600103453,36.5222237358]]]]},"properties":{"uid":0},"id":"fishnet.1"},{"type":"Feature","geometry":{"type":"MultiPolygon","coordinates":[[[[127.2650686665,36.5222237358],[127.2650686665,36.5262684443],[127.2701269878,36.5262684443],[127.2701269878,36.5222237358],[127.2650686665,36.5222237358]]]]},"properties":{"uid":0},"id":"fishnet.2"},{"type":"Feature","geometry":{"type":"MultiPolygon","coordinates":[[[[127.2600103453,36.5262684443],[127.2600103453,36.5303131528],[127.2650686665,36.5303131528],[127.2650686665,36.5262684443],[127.2600103453,36.5262684443]]]]},"properties":{"uid":0},"id":"fishnet.3"},{"type":"Feature","geometry":{"type":"MultiPolygon","coordinates":[[[[127.2650686665,36.5262684443],[127.2650686665,36.5303131528],[127.2701269878,36.5303131528],[127.2701269878,36.5262684443],[127.2650686665,36.5262684443]]]]},"properties":{"uid":0},"id":"fishnet.4"}]})
# Out:
#                 type                                           features
# 0  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 1  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 2  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 3  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...

# %%
multipolys = [{"type":"MultiPolygon",
"coordinates":[
[
[
[
127.2600103453,
36.5222237358
],
[
127.2600103453,
36.5262684443
],
[
127.2650686665,
36.5262684443
],
[
127.2650686665,
36.5222237358
],
[
127.2600103453,
36.5222237358
]
]
]
]
}, {"type":"MultiPolygon","coordinates":[[[[127.2650686665,36.5222237358],[127.2650686665,36.5262684443],[127.2701269878,36.5262684443],[127.2701269878,36.5222237358],[127.2650686665,36.5222237358]]]]},
{"type":"MultiPolygon","coordinates":[[[[127.2600103453,36.5262684443],[127.2600103453,36.5303131528],[127.2650686665,36.5303131528],[127.2650686665,36.5262684443],[127.2600103453,36.5262684443]]]]},
                        {"type":"MultiPolygon","coordinates":[[[[127.2650686665,36.5262684443],[127.2650686665,36.5303131528],[127.2701269878,36.5303131528],[127.2701269878,36.5262684443],[127.2650686665,36.5262684443]]]]}]

# %%
test = gpd.GeoDataFrame(multipolys)

# %%
multipolys
# Out:
# [{'type': 'MultiPolygon',
#   'coordinates': [[[[127.2600103453, 36.5222237358],
#      [127.2600103453, 36.5262684443],
#      [127.2650686665, 36.5262684443],
#      [127.2650686665, 36.5222237358],
#      [127.2600103453, 36.5222237358]]]]},
#  {'type': 'MultiPolygon',
#   'coordinates': [[[[127.2650686665, 36.5222237358],
#      [127.2650686665, 36.5262684443],
#      [127.2701269878, 36.5262684443],
#      [127.2701269878, 36.5222237358],
#      [127.2650686665, 36.5222237358]]]]},
#  {'type': 'MultiPolygon',
#   'coordinates': [[[[127.2600103453, 36.5262684443],
#      [127.2600103453, 36.5303131528],
#      [127.2650686665, 36.5303131528],
#      [127.2650686665, 36.5262684443],
#      [127.2600103453, 36.5262684443]]]]},
#  {'type': 'MultiPolygon',
#   'coordinates': [[[[127.2650686665, 36.5262684443],
#      [127.2650686665, 36.5303131528],
#      [127.2701269878, 36.5303131528],
#      [127.2701269878, 36.5262684443],
#      [127.2650686665, 36.5262684443]]]]}]

# %%
from shapely.geometry import shape
geom = [shape(i) for i in multipolys]
new_df = gpd.GeoDataFrame({'geometry':geom})

# %%
new_df.head()
# Out:
#                                             geometry
# 0  MULTIPOLYGON (((127.26001 36.52222, 127.26001 ...
# 1  MULTIPOLYGON (((127.26507 36.52222, 127.26507 ...
# 2  MULTIPOLYGON (((127.26001 36.52627, 127.26001 ...
# 3  MULTIPOLYGON (((127.26507 36.52627, 127.26507 ...

# %%
new_df.plot()

# %%
test.coordinates.loc[0][0][0]
# Out:
# [[127.2600103453, 36.5222237358],
#  [127.2600103453, 36.5262684443],
#  [127.2650686665, 36.5262684443],
#  [127.2650686665, 36.5222237358],
#  [127.2600103453, 36.5222237358]]

# %%
gpd.__version__
# Out:
# '0.8.0'

# %%
countries = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))

countries.tail(3)
# Out:
#       pop_est      continent                 name iso_a3  gdp_md_est  \
# 174   1895250         Europe               Kosovo    -99     18490.0
# 175   1218208  North America  Trinidad and Tobago    TTO     43570.0
# 176  13026129         Africa             S. Sudan    SSD     20880.0
#
#                                               geometry
# 174  POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175  POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...

# %%
countries.geometry
# Out:
# 0      MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1      POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2      POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3      MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4      MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
#                              ...
# 172    POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173    POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174    POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175    POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176    POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
# Name: geometry, Length: 177, dtype: geometry

# %%
countries.geometry.loc[3]
