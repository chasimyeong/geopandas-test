# %%
import geopandas as gpd
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = 'NanumGothic'
plt.rcParams["font.size"] = 13
plt.rcParams["figure.figsize"] = (10,10)

# %%
df = gpd.read_file("CTPRVN.shp", encoding = 'euc-kr')

# %%
_df = gpd.read_file("seoul_3857.shp", encoding = 'euc-kr')

# %%
df.head()
# Out:
#   CTPRVN_CD CTP_ENG_NM CTP_KOR_NM  \
# 0        11      Seoul      서울특별시
# 1        26      Busan      부산광역시
# 2        27      Daegu      대구광역시
# 3        28    Incheon      인천광역시
# 4        29    Gwangju      광주광역시
#
#                                             geometry
# 0  POLYGON ((966987.226 1941110.946, 966987.119 1...
# 1  MULTIPOLYGON (((1138209.365 1673609.179, 11381...
# 2  POLYGON ((1107777.593 1780522.269, 1107845.409...
# 3  MULTIPOLYGON (((897904.035 1961082.190, 897886...
# 4  POLYGON ((932712.687 1696168.692, 932781.680 1...

# %%
df[df.CTP_KOR_NM == '서울특별시'].plot()

# %%
df[df.CTP_KOR_NM == '서울특별시'].crs
# Out:
# <Projected CRS: PROJCS["PCS_ITRF2000_TM",GEOGCS["ITRF2000",DATUM[" ...>
# Name: PCS_ITRF2000_TM
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Transverse Mercator
# Datum: International Terrestrial Reference Frame 2000
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
df[df.CTP_KOR_NM == '부산광역시'].geometry
# Out:
# 1    MULTIPOLYGON (((1138209.365 1673609.179, 11381...
# Name: geometry, dtype: geometry

# %%
new_df = df.to_crs(epsg=3857)

# %%
new_df[new_df.CTP_KOR_NM == '서울특별시'].plot()

# %%
new_df[new_df.CTP_KOR_NM == '서울특별시'].to_file("seoul_3857.shp", encoding='euc-kr')

# %%
new_df.to_file("seoul_3857.shp", encoding='euc-kr')

# %%
gpd.read_file("new_convert.shp")
# Out:
#    CTPRVN_CD         CTP_ENG_NM CTP_KOR_NM  \
# 0         11              Seoul      서울특별시
# 1         26              Busan      부산광역시
# 2         27              Daegu      대구광역시
# 3         28            Incheon      인천광역시
# 4         29            Gwangju      광주광역시
# 5         30            Daejeon      대전광역시
# 6         31              Ulsan      울산광역시
# 7         36          Sejong-si    세종특별자치시
# 8         41        Gyeonggi-do        경기도
# 9         42         Gangwon-do        강원도
# 10        43  Chungcheongbuk-do       충청북도
# 11        44  Chungcheongnam-do       충청남도
# 12        45       Jeollabuk-do       전라북도
# 13        46        Jellanam-do       전라남도
# 14        47   Gyeongsangbuk-do       경상북도
# 15        48   Gyeongsangnam-do       경상남도
# 16        50            Jeju-do    제주특별자치도
#
#                                              geometry
# 0   POLYGON ((127.12667 37.46863, 127.12667 37.468...
# 1   MULTIPOLYGON (((129.01542 35.04808, 129.01515 ...
# ...

# %%
xml = '<?xml version="1.0" encoding="UTF-8"?>\
<wps:Execute version="1.0.0" service="WPS"\
 xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.opengis.net/wps/1.0.0" xmlns:wfs="http://www.opengis.net/wfs" xmlns:wps="http://www.opengis.net/wps/1.0.0" xmlns:ows="http://www.opengis.net/ows/1.1" xmlns:gml="http://www.opengis.net/gml" xmlns:ogc="http://www.opengis.net/ogc" xmlns:wcs="http://www.opengis.net/wcs/1.1.1" xmlns:xlink="http://www.w3.org/1999/xlink" xsi:schemaLocation="http://www.opengis.net/wps/1.0.0 http://schemas.opengis.net/wps/1.0.0/wpsAll.xsd">\
    <ows:Identifier>statistics:FishnetCount</ows:Identifier>\
    <wps:DataInputs>\
        <wps:Input>\
            <ows:Identifier>extent</ows:Identifier>\
            <wps:Data>\
                <wps:BoundingBoxData crs="EPSG:3857" dimensions="2">\
                    <ows:LowerCorner>1.4111357E7 4498975.0</ows:LowerCorner>\
                    <ows:UpperCorner>1.4158036E7 4537337.0</ows:UpperCorner>\
                </wps:BoundingBoxData>\
            </wps:Data>\
        </wps:Input>\
        <wps:Input>\
            <ows:Identifier>boundsSource</ows:Identifier>\
            <wps:Reference mimeType="text/xml; subtype=wfs-collection/1.0" xlink:href="http://geoserver/wfs" method="POST">\
                <wps:Body>\
                    <wfs:GetFeature service="WFS" version="1.1.0" outputFormat="GML3" xmlns:foss="http://www.opengeospatial.net/foss">\
                        <wfs:Query typeName="mago3d:seoul_3857"/>\
                    </wfs:GetFeature>\
                </wps:Body>\
            </wps:Reference>\
        </wps:Input>\
        <wps:Input>\
            <ows:Identifier>columns</ows:Identifier>\
            <wps:Data>\
                <wps:LiteralData>25</wps:LiteralData>\
            </wps:Data>\
        </wps:Input>\
        <wps:Input>\
            <ows:Identifier>rows</ows:Identifier>\
            <wps:Data>\
                <wps:LiteralData>25</wps:LiteralData>\
            </wps:Data>\
        </wps:Input>\
    </wps:DataInputs>\
    <wps:ResponseForm>\
        <wps:RawDataOutput mimeType="application/vnd.geo+json">\
            <ows:Identifier>result</ows:Identifier>\
        </wps:RawDataOutput>\
    </wps:ResponseForm>\
</wps:Execute>'

# %%
xml = '<?xml version="1.0" encoding="UTF-8"?>\
<wps:Execute version="1.0.0" service="WPS"\
 xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.opengis.net/wps/1.0.0" xmlns:wfs="http://www.opengis.net/wfs" xmlns:wps="http://www.opengis.net/wps/1.0.0" xmlns:ows="http://www.opengis.net/ows/1.1" xmlns:gml="http://www.opengis.net/gml" xmlns:ogc="http://www.opengis.net/ogc" xmlns:wcs="http://www.opengis.net/wcs/1.1.1" xmlns:xlink="http://www.w3.org/1999/xlink" xsi:schemaLocation="http://www.opengis.net/wps/1.0.0 http://schemas.opengis.net/wps/1.0.0/wpsAll.xsd">\
    <ows:Identifier>statistics:FishnetCount</ows:Identifier>\
    <wps:DataInputs>\
        <wps:Input>\
            <ows:Identifier>extent</ows:Identifier>\
            <wps:Data>\
                <wps:BoundingBoxData crs="EPSG:4326" dimensions="2">\
                    <ows:LowerCorner>127.19931049066805 36.44941898280123</ows:LowerCorner>\
                    <ows:UpperCorner>127.32576852118987 36.55053669535394</ows:UpperCorner>\
                </wps:BoundingBoxData>\
            </wps:Data>\
        </wps:Input>\
        <wps:Input>\
            <ows:Identifier>boundsSource</ows:Identifier>\
            <wps:Reference mimeType="text/xml; subtype=wfs-collection/1.0" xlink:href="http://geoserver/wfs" method="POST">\
                <wps:Body>\
                    <wfs:GetFeature service="WFS" version="1.1.0" outputFormat="GML3" xmlns:foss="http://www.opengeospatial.net/foss">\
                        <wfs:Query typeName="mago3d:Parcel6-4"/>\
                    </wfs:GetFeature>\
                </wps:Body>\
            </wps:Reference>\
        </wps:Input>\
        <wps:Input>\
            <ows:Identifier>columns</ows:Identifier>\
            <wps:Data>\
                <wps:LiteralData>25</wps:LiteralData>\
            </wps:Data>\
        </wps:Input>\
        <wps:Input>\
            <ows:Identifier>rows</ows:Identifier>\
            <wps:Data>\
                <wps:LiteralData>25</wps:LiteralData>\
            </wps:Data>\
        </wps:Input>\
    </wps:DataInputs>\
    <wps:ResponseForm>\
        <wps:RawDataOutput mimeType="application/vnd.geo+json">\
            <ows:Identifier>result</ows:Identifier>\
        </wps:RawDataOutput>\
    </wps:ResponseForm>\
</wps:Execute>'

# %%
print(xml)
# Out:
# <?xml version="1.0" encoding="UTF-8"?><wps:Execute version="1.0.0" service="WPS" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.opengis.net/wps/1.0.0" xmlns:wfs="http://www.opengis.net/wfs" xmlns:wps="http://www.opengis.net/wps/1.0.0" xmlns:ows="http://www.opengis.net/ows/1.1" xmlns:gml="http://www.opengis.net/gml" xmlns:ogc="http://www.opengis.net/ogc" xmlns:wcs="http://www.opengis.net/wcs/1.1.1" xmlns:xlink="http://www.w3.org/1999/xlink" xsi:schemaLocation="http://www.opengis.net/wps/1.0.0 http://schemas.opengis.net/wps/1.0.0/wpsAll.xsd">    <ows:Identifier>statistics:FishnetCount</ows:Identifier>    <wps:DataInputs>        <wps:Input>            <ows:Identifier>extent</ows:Identifier>            <wps:Data>                <wps:BoundingBoxData crs="EPSG:4326" dimensions="2">                    <ows:LowerCorner>127.19931049066805 36.44941898280123</ows:LowerCorner>                    <ows:UpperCorner>127.32576852118987 36.55053669535394</ows:UpperCorner>     
# ...

# %%
import requests

url = 'http://localhost:8080/geoserver/wps'
headers = {'Content-Type': 'text/xml;charset=utf-8'}
geojson = requests.post(url, data=xml, headers = headers).text
print(geojson)
# Out:
# {"type":"FeatureCollection","crs":{"type":"name","properties":{"name":"EPSG:3857"}},"features":[{"type":"Feature","geometry":{"type":"MultiPolygon","coordinates":[[[[1.4126294280000001E7,4498975],[1.4126294280000001E7,4500509.48],[1.4128161440000001E7,4500509.48],[1.4128161440000001E7,4498975],[1.4126294280000001E7,4498975]]]]},"properties":{"uid":0},"id":"fishnet.1"},{"type":"Feature","geometry":{"type":"MultiPolygon","coordinates":[[[[1.4130028600000001E7,4498975],[1.4130028600000001E7,4500509.48],[1.4131895760000002E7,4500509.48],[1.4131895760000002E7,4498975],[1.4130028600000001E7,4498975]]]]},"properties":{"uid":0},"id":"fishnet.2"},{"type":"Feature","geometry":{"type":"MultiPolygon","coordinates":[[[[1.4131895760000002E7,4498975],[1.4131895760000002E7,4500509.48],[1.4133762920000002E7,4500509.48],[1.4133762920000002E7,4498975],[1.4131895760000002E7,4498975]]]]},"properties":{"uid":0},"id":"fishnet.3"},{"type":"Feature","geometry":{"type":"MultiPolygon","coordinates":[[[[1.41412
# ...

# %%
import json

geodict = json.loads(geojson)
geodict
# Out:
# {'type': 'FeatureCollection',
#  'crs': {'type': 'name', 'properties': {'name': 'EPSG:3857'}},
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[14126294.280000001, 4498975],
#        [14126294.280000001, 4500509.48],
#        [14128161.440000001, 4500509.48],
#        [14128161.440000001, 4498975],
#        [14126294.280000001, 4498975]]]]},
#    'properties': {'uid': 0},
#    'id': 'fishnet.1'},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[14130028.600000001, 4498975],
#        [14130028.600000001, 4500509.48],
#        [14131895.760000002, 4500509.48],
#        [14131895.760000002, 4498975],
#        [14130028.600000001, 4498975]]]]},
#    'properties': {'uid': 0},
#    'id': 'fishnet.2'},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[14131895.760000002, 4498975],
#        [14131895.760000002, 4500509.48],
# ...

# %%
df_list = []

for d in geodict['features']:
       
    df_list.append(d['geometry'])

df_list
# Out:
# [{'type': 'MultiPolygon',
#   'coordinates': [[[[14126294.280000001, 4498975],
#      [14126294.280000001, 4500509.48],
#      [14128161.440000001, 4500509.48],
#      [14128161.440000001, 4498975],
#      [14126294.280000001, 4498975]]]]},
#  {'type': 'MultiPolygon',
#   'coordinates': [[[[14130028.600000001, 4498975],
#      [14130028.600000001, 4500509.48],
#      [14131895.760000002, 4500509.48],
#      [14131895.760000002, 4498975],
#      [14130028.600000001, 4498975]]]]},
#  {'type': 'MultiPolygon',
#   'coordinates': [[[[14131895.760000002, 4498975],
#      [14131895.760000002, 4500509.48],
#      [14133762.920000002, 4500509.48],
#      [14133762.920000002, 4498975],
#      [14131895.760000002, 4498975]]]]},
#  {'type': 'MultiPolygon',
#   'coordinates': [[[[14141231.560000002, 4498975],
#      [14141231.560000002, 4500509.48],
#      [14143098.720000003, 4500509.48],
#      [14143098.720000003, 4498975],
#      [14141231.560000002, 4498975]]]]},
#  {'type': 'MultiPolygon',
# ...

# %%
# df_dict = {'type' : [],
#           'coordinates' : []}

# for d in geodict['features']:
       
#     _dict = d['geometry']
#     df_dict['type'].append(_dict['type'])
#     df_dict['coordinates'].append(_dict['coordinates'])
    
# test_df = pd.DataFrame(df_dict)

# %%
df_list
# Out:
# [{'type': 'Feature',
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[14126294.280000001, 4498975],
#       [14126294.280000001, 4500509.48],
#       [14128161.440000001, 4500509.48],
#       [14128161.440000001, 4498975],
#       [14126294.280000001, 4498975]]]]},
#   'properties': {'uid': 0},
#   'id': 'fishnet.1'},
#  {'type': 'Feature',
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[14130028.600000001, 4498975],
#       [14130028.600000001, 4500509.48],
#       [14131895.760000002, 4500509.48],
#       [14131895.760000002, 4498975],
#       [14130028.600000001, 4498975]]]]},
#   'properties': {'uid': 0},
#   'id': 'fishnet.2'},
#  {'type': 'Feature',
#   'geometry': {'type': 'MultiPolygon',
#    'coordinates': [[[[14131895.760000002, 4498975],
#       [14131895.760000002, 4500509.48],
#       [14133762.920000002, 4500509.48],
#       [14133762.920000002, 4498975],
#       [14131895.760000002, 4498975]]]]},
#   'properties': {'uid': 0},
# ...

# %%
from shapely.geometry import shape
geom = [shape(i) for i in df_list]
new_df = gpd.GeoDataFrame({'geometry':geom})

# %%
_df
# Out:
#   CTPRVN_CD CTP_ENG_NM CTP_KOR_NM  \
# 0        11      Seoul      서울특별시
#
#                                             geometry
# 0  POLYGON ((14151675.863 4504629.945, 14151675.7...

# %%
base = _df.boundary.plot()
new_df.boundary.plot(ax=base)

# %%
import requests

url = 'http://localhost:8080/geoserver/wps'
headers = {'Content-Type': 'text/xml;charset=utf-8'}
print(requests.post(url, data=xml, headers = headers).text)
# Out:
# {"type":"FeatureCollection","features":[{"type":"Feature","geometry":{"type":"MultiPolygon","coordinates":[[[[127.2600103453,36.5222237358],[127.2600103453,36.5262684443],[127.2650686665,36.5262684443],[127.2650686665,36.5222237358],[127.2600103453,36.5222237358]]]]},"properties":{"uid":0},"id":"fishnet.1"},{"type":"Feature","geometry":{"type":"MultiPolygon","coordinates":[[[[127.2650686665,36.5222237358],[127.2650686665,36.5262684443],[127.2701269878,36.5262684443],[127.2701269878,36.5222237358],[127.2650686665,36.5222237358]]]]},"properties":{"uid":0},"id":"fishnet.2"},{"type":"Feature","geometry":{"type":"MultiPolygon","coordinates":[[[[127.2600103453,36.5262684443],[127.2600103453,36.5303131528],[127.2650686665,36.5303131528],[127.2650686665,36.5262684443],[127.2600103453,36.5262684443]]]]},"properties":{"uid":0},"id":"fishnet.3"},{"type":"Feature","geometry":{"type":"MultiPolygon","coordinates":[[[[127.2650686665,36.5262684443],[127.2650686665,36.5303131528],[127.2701269878,36.5
# ...

# %%
import pandas as pd

tt = pd.DataFrame([[127.2600103453,36.5222237358], [127.2600103453,36.5262684443],
             [127.2650686665,36.5262684443], [127.2600103453,36.5222237358], 
             [127.2600103453,36.5222237358], [127.2650686665,36.5222237358], 
             [127.2650686665,36.5262684443], [127.2701269878,36.5262684443],
             [127.2701269878,36.5222237358], [127.2650686665,36.5222237358],
             [127.2600103453,36.5262684443], [127.2600103453,36.5303131528],
             [127.2650686665,36.5303131528], [127.2650686665,36.5262684443],
             [127.2600103453,36.5262684443], [127.2650686665,36.5262684443],
             [127.2650686665,36.5303131528], [127.2701269878,36.5303131528],
             [127.2701269878,36.5262684443], [127.2650686665,36.5262684443]], columns = ['x', 'y'])

# %%
plt.scatter(tt.x, tt.y)
